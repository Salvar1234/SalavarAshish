# %%
""" importing the required libraries """
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def readFile(link):
  """ reading the csv files """
  df = pd.read_csv(link)
  countries = df.iloc[:,0:1]
  years = df.iloc[:,1:]
  return countries, years # returns the country data frame and year data frame

def statisticalProperties(country_list, years):
  """ Computing the Statistical Properties for the given data """
  average = list(years.mean(axis = 1)) 
  maximum_growth = list(years.max(axis = 1))
  minimum_growth = list(years.min(axis = 1))
  data = [country_list,average,maximum_growth,minimum_growth]
  df = pd.DataFrame(data).transpose()
  df.columns = ['Country Name', 'Average Population Growth', 'Maximum Population Growth', 'Minimum Population Growth']
  display(df)

def graph(country_list,years):
  """ Drawing the line plot for the data """
  yname = list(years.columns)
  ls = years.values.tolist()
  print("\n")
  plt.figure(figsize=[10,5])
  for i in range(10):
    plt.plot(yname,ls[i], lw = 2, ls='dashdot',label=country[i])
  plt.legend()
  plt.title("Population growth for different countries",size=20)
  plt.xlabel("Year",size=15)
  plt.ylabel("Population growth (annual %)",size=15)
  plt.show()
  plt.close()

def correlation_plot(link):
  """ Mapping the correlations on different indicators """
  data = pd.read_csv(link)
  cormat = sns.heatmap(data.corr(), annot=True,cmap='RdYlGn',linewidths=0.30)
  plt.title("Correlation between different indicators for India\n\n")
  display(cormat)

link = "/content/Population_growth.csv"
countries, years = readFile(link)
country_list = countries['Country Name'].tolist() # converting the country data frame to list
display(countries,years)

statisticalProperties(country_list,years)

graph(country_list,years)

correlation_plot('/content/India.csv')
# Out:
#            Country Name
# 0  United Arab Emirates
# 1             Australia
# 2                Canada
# 3                 China
# 4               Germany
# 5                France
# 6        United Kingdom
# 7                 India
# 8                Mexico
# 9          South Africa
#        2000       2005      2010      2015      2020
# 0  5.510750  12.019928  7.687222  0.527292  1.219429
# 1  1.192272   1.319790  1.555490  1.439217  1.282933
# 2  0.931282   0.944467  1.111864  0.746339  1.152797
# 3  0.787957   0.588125  0.482960  0.581456  0.238041
# 4  0.135432  -0.056778 -0.153198  0.865703  0.081693
# 5  0.684946   0.753799  0.494041  0.355569  0.194582
# 6  0.357301   0.686611  0.783889  0.792368  0.365409
# 7  1.768126   1.579709  1.350338  1.116896  0.989414
# 8  1.441097   1.415817  1.438141  1.241165  1.058240
# 9  1.409022   1.237741  1.455282  1.532243  1.273356
#            Country Name Average Population Growth Maximum Population Growth  \
# ...
